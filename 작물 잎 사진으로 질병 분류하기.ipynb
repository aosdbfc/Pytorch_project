# %% [markdown]
# ## 실험 설계를 위한 데이터 분할

# %%
import os
import shutil

original_dataset_dir = './dataset'
classes_list = os.listdir(original_dataset_dir)

base_dir = './splitted'
os.mkdir(base_dir)

train_dir = os.path.join(base_dir, 'train')
os.mkdir(train_dir)

validation_dir = os.path.join(base_dir, 'val')
os.mkdir(validation_dir)

test_dir = os.path.join(base_dir,'test')
os.mkdir(test_dir)

for clss in classes_list:
    os.mkdir(os.path.join(train_dir, clss))
    os.mkdir(os.path.join(validation_dir,clss))
    os.mkdir(os.path.join(test_dir,clss))

# %%
import math

for clss in classes_list:
    path = os.path.join(original_dataset_dir, clss)
    fnames = os.listdir(path)
    
    train_size = math.floor(len(fnames) * 0.6)
    validation_size = math.floor(len(fnames) * 0.2)
    test_size = math.floor(len(fnames) * 0.2)
    
    train_fnames = fnames[:train_size]
    print(clss, len(train_fnames))
    for fname in train_fnames:
        src = os.path.join(path, fname)
        dst = os.path.join(os.path.join(train_dir,clss), fname)
        shutil.copyfile(src,dst)
        
    validation_fnames = fnames[train_size:(validation_size + train_size)]
    print(clss, len(validation_fnames))
    for fname in validation_fnames:
        src = os.path.join(path,fname)
        dst = os.path.join(os.path.join(validation_dir, clss), fname)
        shutil.copyfile(src,dst)
        
    test_fnames = fnames[(train_size + validation_size):
                        (validation_size + train_size + test_size)]
    
    print(clss, len(test_fnames))
    for fname in test_fnames:
        src = os.path.join(path,fname)
        dst = os.path.join(os.path.join(test_dir,clss), fname)
        shutil.copyfile(src,dst)
# Out:
# Apple___Apple_scab 378
# Apple___Apple_scab 126
# Apple___Apple_scab 126
# Apple___Black_rot 372
# Apple___Black_rot 124
# Apple___Black_rot 124
# Apple___Cedar_apple_rust 165
# Apple___Cedar_apple_rust 55
# Apple___Cedar_apple_rust 55
# Apple___healthy 987
# Apple___healthy 329
# Apple___healthy 329
# Cherry___healthy 512
# Cherry___healthy 170
# Cherry___healthy 170
# Cherry___Powdery_mildew 631
# Cherry___Powdery_mildew 210
# Cherry___Powdery_mildew 210
# Corn___Cercospora_leaf_spot Gray_leaf_spot 307
# Corn___Cercospora_leaf_spot Gray_leaf_spot 102
# Corn___Cercospora_leaf_spot Gray_leaf_spot 102
# Corn___Common_rust 715
# Corn___Common_rust 238
# Corn___Common_rust 238
# Corn___healthy 697
# Corn___healthy 232
# Corn___healthy 232
# Corn___Northern_Leaf_Blight 591
# Corn___Northern_Leaf_Blight 197
# Corn___Northern_Leaf_Blight 197
# Grape___Black_rot 708
# Grape___Black_rot 236
# Grape___Black_rot 236
# Grape___Esca_(Black_Measles) 829
# Grape___Esca_(Black_Measles) 276
# Grape___Esca_(Black_Measles) 276
# Grape___healthy 253
# Grape___healthy 84
# Grape___healthy 84
# Grape___Leaf_blight_(Isariopsis_Leaf_Spot) 645
# Grape___Leaf_blight_(Isariopsis_Leaf_Spot) 215
# Grape___Leaf_blight_(Isariopsis_Leaf_Spot) 215
# Peach___Bacterial_spot 1378
# Peach___Bacterial_spot 459
# Peach___Bacterial_spot 459
# Peach___healthy 216
# Peach___healthy 72
# Peach___healthy 72
# Pepper,_bell___Bacterial_spot 598
# Pepper,_bell___Bacterial_spot 199
# Pepper,_bell___Bacterial_spot 199
# Pepper,_bell___healthy 886
# Pepper,_bell___healthy 295
# Pepper,_bell___healthy 295
# Potato___Early_blight 600
# Potato___Early_blight 200
# Potato___Early_blight 200
# Potato___healthy 91
# Potato___healthy 30
# Potato___healthy 30
# Potato___Late_blight 600
# Potato___Late_blight 200
# Potato___Late_blight 200
# Strawberry___healthy 273
# Strawberry___healthy 91
# Strawberry___healthy 91
# Strawberry___Leaf_scorch 665
# Strawberry___Leaf_scorch 221
# Strawberry___Leaf_scorch 221
# Tomato___Bacterial_spot 1276
# Tomato___Bacterial_spot 425
# Tomato___Bacterial_spot 425
# Tomato___Early_blight 600
# Tomato___Early_blight 200
# Tomato___Early_blight 200
# Tomato___healthy 954
# Tomato___healthy 318
# Tomato___healthy 318
# Tomato___Late_blight 1145
# Tomato___Late_blight 381
# Tomato___Late_blight 381
# Tomato___Leaf_Mold 571
# Tomato___Leaf_Mold 190
# Tomato___Leaf_Mold 190
# Tomato___Septoria_leaf_spot 1062
# Tomato___Septoria_leaf_spot 354
# Tomato___Septoria_leaf_spot 354
# Tomato___Spider_mites Two-spotted_spider_mite 1005
# Tomato___Spider_mites Two-spotted_spider_mite 335
# Tomato___Spider_mites Two-spotted_spider_mite 335
# Tomato___Target_Spot 842
# Tomato___Target_Spot 280
# Tomato___Target_Spot 280
# Tomato___Tomato_mosaic_virus 223
# Tomato___Tomato_mosaic_virus 74
# Tomato___Tomato_mosaic_virus 74
# Tomato___Tomato_Yellow_Leaf_Curl_Virus 3214
# Tomato___Tomato_Yellow_Leaf_Curl_Virus 1071
# Tomato___Tomato_Yellow_Leaf_Curl_Virus 1071

# %% [markdown]
# ### [베이스라인 모델 학습을 위한 준비]

# %%
import torch

USE_CUDA = torch.cuda.is_available()
DEVICE = torch.device('cuda' if USE_CUDA else 'cpu')

BATCH_SIZE = 256
EPOCH = 30

import torchvision.transforms as transforms
from torchvision.datasets import ImageFolder

transform_base = transforms.Compose([transforms.Resize((64,64)),
                                    transforms.ToTensor()])

train_dataset = ImageFolder(root='./splitted/train',
                           transform = transform_base)
val_dataset = ImageFolder(root='./splitted/val',
                         transform = transform_base)

from torch.utils.data import DataLoader

train_loader = torch.utils.data.DataLoader(train_dataset,
                                          batch_size = BATCH_SIZE, shuffle = True,
                                           num_workers = 4)
val_loader = torch.utils.data.DataLoader(val_dataset,
                                        batch_size = BATCH_SIZE, shuffle = True, 
                                        num_workers = 4)
# Out:
# WARNING:tensorflow:From C:\Users\aosdb\anaconda3\lib\site-packages\keras\src\losses.py:2976: The name tf.losses.sparse_softmax_cross_entropy is deprecated. Please use tf.compat.v1.losses.sparse_softmax_cross_entropy instead.

# %%
import torch.nn as nn
import torch.nn.functional as F
import torch.optim as optim

class Net(nn.Module):
    
    def __init__(self):
        
        super(Net, self).__init__()
        
        self.conv1 = nn.Conv2d(3, 32, 3, padding=1)
        self.pool = nn.MaxPool2d(2,2)
        self.conv2 = nn.Conv2d(32, 64, 3, padding=1)
        self.conv3 = nn.Conv2d(64,64,3, padding=1)
        
        self.fc1 = nn.Linear(4096,512)
        self.fc2 = nn.Linear(512,33)
        
    def forward(self,x):
        x = self.conv1(x)
        x = F.relu(x)
        x = self.pool(x)
        x = F.dropout(x, p = 0.25, training=self.training)
        
        x = self.conv2(x)
        x = F.relu(x)
        x = self.pool(x)
        x = F.dropout(x, p=0.25, training=self.training)
        
        x = self.conv3(x)
        x = F.relu(x)
        x = self.pool(x)
        x = F.dropout(x, p=0.25, training=self.training)
        
        x = x.view(-1,4096)
        x = self.fc1(x)
        x = F.relu(x)
        x = F.dropout(x, p=0.5, training=self.training)
        x = self.fc2(x)
        
        return F.log_softmax(x, dim=1)
    
model_base = Net().to(DEVICE)
optimizer = optim.Adam(model_base.parameters(), lr=0.001)

# %% [markdown]
# ### [모델 학습을 위한 함수]

# %%
def train(model, train_loader, optimizer):
    model.train()
    for batch_idx, (data, target) in enumerate(train_loader):
        data, target = data.to(DEVICE), target.to(DEVICE)
        optimizer.zero_grad()
        output = model(data)
        loss = F.cross_entropy(output, target)
        loss.backward()
        optimizer.step()

# %% [markdown]
# ### [모델 평가를 위한 함수]

# %%
def evaluate(model, test_loader):
    model.eval()
    test_loss = 0
    correct = 0
    
    with torch.no_grad():
        for data, target in test_loader:
            data, target = data.to(DEVICE), target.to(DEVICE)
            output = model(data)
            
            test_loss += F.cross_entropy(output,
                                        target, reduction='sum').item()
            
            pred = output.max(1, keepdim =True)[1]
            correct += pred.eq(target.view_as(pred)).sum().item()
    
    test_loss /= len(test_loader.dataset)
    test_accuracy = 100. * correct / len(test_loader.dataset)
    return test_loss, test_accuracy

# %%
import time
import copy

def train_baseline(model, train_loader, val_loader,
                  optimizer, num_epoch = 30):
    best_acc = 0.0
    best_model_wts = copy.deepcopy(model.state_dict())
    
    for epoch in range(1, num_epoch +1):
        since = time.time()
        train(model, train_loader, optimizer)
        train_loss, train_acc = evaluate(model, train_loader)
        val_loss, val_acc = evaluate(model, val_loader)
        
        if val_acc > best_acc:
            best_acc = val_acc
            best_model_wts = copy.deepcopy(model.state_dict())
            
        time_elapsed = time.time() - since
        print('=======================epoch {}============================='.format(epoch))
        
        print('train Loss: {:.4f}, Accuracy: {:.2f}%'.format(train_loss, train_acc))
        print('val Loss: {:.4f}, Accuracy: {:.2f}%'.format(val_loss, val_acc))
        print('Completed in {:.0f}m, {:.0f}s'.format(time_elapsed // 60 , time_elapsed % 60))
        
    model.load_state_dict(best_model_wts)
    return model

base = train_baseline(model_base, train_loader, val_loader, optimizer, EPOCH)

torch.save(base, 'baseline.pt')
# Out:
# =======================epoch 1=============================
# train Loss: 0.8680, Accuracy: 72.80%
# val Loss: 0.9234, Accuracy: 70.99%
# Completed in 4m, 4s
# =======================epoch 2=============================
# train Loss: 0.6443, Accuracy: 80.67%
# val Loss: 0.7042, Accuracy: 78.75%
# Completed in 3m, 46s
# =======================epoch 3=============================
# train Loss: 0.5443, Accuracy: 83.09%
# val Loss: 0.6151, Accuracy: 80.51%
# Completed in 3m, 41s
# =======================epoch 4=============================
# train Loss: 0.4693, Accuracy: 85.35%
# val Loss: 0.5452, Accuracy: 82.58%
# Completed in 3m, 37s
# =======================epoch 5=============================
# train Loss: 0.4383, Accuracy: 86.62%
# val Loss: 0.5153, Accuracy: 83.92%
# Completed in 3m, 37s
# =======================epoch 6=============================
# train Loss: 0.3670, Accuracy: 88.44%
# val Loss: 0.4572, Accuracy: 85.00%
# Completed in 3m, 40s
# =======================epoch 7=============================
# train Loss: 0.3210, Accuracy: 90.20%
# val Loss: 0.4133, Accuracy: 86.68%
# Completed in 4m, 12s
# =======================epoch 8=============================
# train Loss: 0.2916, Accuracy: 91.33%
# val Loss: 0.3917, Accuracy: 87.95%
# Completed in 4m, 39s
# =======================epoch 9=============================
# train Loss: 0.2921, Accuracy: 91.31%
# val Loss: 0.3882, Accuracy: 87.52%
# Completed in 4m, 29s
# =======================epoch 10=============================
# train Loss: 0.2508, Accuracy: 92.19%
# val Loss: 0.3568, Accuracy: 88.25%
# Completed in 3m, 8s
# =======================epoch 11=============================
# train Loss: 0.2220, Accuracy: 93.14%
# val Loss: 0.3305, Accuracy: 89.08%
# Completed in 3m, 12s
# =======================epoch 12=============================
# train Loss: 0.2040, Accuracy: 93.79%
# val Loss: 0.3164, Accuracy: 89.87%
# Completed in 3m, 5s
# =======================epoch 13=============================
# train Loss: 0.1932, Accuracy: 93.83%
# val Loss: 0.3086, Accuracy: 89.97%
# Completed in 2m, 52s
# =======================epoch 14=============================
# train Loss: 0.1738, Accuracy: 94.69%
# val Loss: 0.2961, Accuracy: 90.27%
# Completed in 2m, 53s
# =======================epoch 15=============================
# train Loss: 0.1478, Accuracy: 95.86%
# val Loss: 0.2646, Accuracy: 91.59%
# Completed in 2m, 55s
# =======================epoch 16=============================
# train Loss: 0.1387, Accuracy: 95.63%
# val Loss: 0.2655, Accuracy: 90.75%
# Completed in 2m, 54s
# =======================epoch 17=============================
# train Loss: 0.1414, Accuracy: 95.84%
# val Loss: 0.2668, Accuracy: 91.46%
# Completed in 2m, 54s
# =======================epoch 18=============================
# train Loss: 0.1331, Accuracy: 96.02%
# val Loss: 0.2671, Accuracy: 91.09%
# Completed in 2m, 53s
# =======================epoch 19=============================
# train Loss: 0.1170, Accuracy: 96.77%
# val Loss: 0.2519, Accuracy: 91.70%
# Completed in 2m, 53s
# =======================epoch 20=============================
# train Loss: 0.1176, Accuracy: 96.82%
# val Loss: 0.2623, Accuracy: 91.49%
# Completed in 2m, 56s
# =======================epoch 21=============================
# train Loss: 0.1098, Accuracy: 96.74%
# val Loss: 0.2530, Accuracy: 91.53%
# Completed in 2m, 54s
# =======================epoch 22=============================
# train Loss: 0.0820, Accuracy: 97.70%
# val Loss: 0.2280, Accuracy: 92.68%
# Completed in 2m, 55s
# =======================epoch 23=============================
# train Loss: 0.0984, Accuracy: 97.23%
# val Loss: 0.2455, Accuracy: 91.91%
# Completed in 2m, 53s
# =======================epoch 24=============================
# train Loss: 0.0980, Accuracy: 97.17%
# val Loss: 0.2519, Accuracy: 91.68%
# Completed in 2m, 51s
# =======================epoch 25=============================
# train Loss: 0.0681, Accuracy: 98.33%
# val Loss: 0.2126, Accuracy: 93.37%
# Completed in 2m, 51s
# =======================epoch 26=============================
# train Loss: 0.0761, Accuracy: 97.89%
# val Loss: 0.2315, Accuracy: 92.43%
# Completed in 2m, 51s
# =======================epoch 27=============================
# train Loss: 0.0689, Accuracy: 98.34%
# val Loss: 0.2267, Accuracy: 92.65%
# Completed in 2m, 50s
# =======================epoch 28=============================
# train Loss: 0.0588, Accuracy: 98.69%
# val Loss: 0.2048, Accuracy: 93.57%
# Completed in 2m, 49s
# =======================epoch 29=============================
# train Loss: 0.0517, Accuracy: 98.93%
# val Loss: 0.1959, Accuracy: 93.59%
# Completed in 2m, 49s
# =======================epoch 30=============================
# train Loss: 0.0521, Accuracy: 98.82%
# val Loss: 0.2032, Accuracy: 93.64%
# Completed in 2m, 50s

# %% [markdown]
# ### [ 전이학습 ]
#
# - Transfer Learning을 위한 준비

# %%
data_transforms = {
    'train': transforms.Compose([transforms.Resize([64,64]), 
        transforms.RandomHorizontalFlip(), transforms.RandomVerticalFlip(),  
        transforms.RandomCrop(52), transforms.ToTensor(), 
        transforms.Normalize([0.485, 0.456, 0.406], [0.229, 0.224, 0.225]) ]),
    
    'val': transforms.Compose([transforms.Resize([64,64]),  
        transforms.RandomCrop(52), transforms.ToTensor(),
        transforms.Normalize([0.485, 0.456, 0.406], [0.229, 0.224, 0.225]) ])
}

# %%
data_dir = './splitted' 
image_datasets = {x: ImageFolder(root=os.path.join(data_dir, x), transform=data_transforms[x]) for x in ['train', 'val']} 
dataloaders = {x: torch.utils.data.DataLoader(image_datasets[x], batch_size=BATCH_SIZE, shuffle=True, num_workers=4) for x in ['train', 'val']} 
dataset_sizes = {x: len(image_datasets[x]) for x in ['train', 'val']}

class_names = image_datasets['train'].classes

# %% [markdown]
# - Pre-Trained Model 불러오기

# %%
from torchvision import models
 
resnet = models.resnet50(pretrained=True)  
num_ftrs = resnet.fc.in_features   
resnet.fc = nn.Linear(num_ftrs, 33) 
resnet = resnet.to(DEVICE)
 
criterion = nn.CrossEntropyLoss() 
optimizer_ft = optim.Adam(filter(lambda p: p.requires_grad, resnet.parameters()), lr=0.001)
 
from torch.optim import lr_scheduler
exp_lr_scheduler = lr_scheduler.StepLR(optimizer_ft, step_size=7, gamma=0.1)
# Out:
# C:\Users\aosdb\anaconda3\lib\site-packages\torchvision\models\_utils.py:208: UserWarning: The parameter 'pretrained' is deprecated since 0.13 and may be removed in the future, please use 'weights' instead.
#   warnings.warn(
# C:\Users\aosdb\anaconda3\lib\site-packages\torchvision\models\_utils.py:223: UserWarning: Arguments other than a weight enum or `None` for 'weights' are deprecated since 0.13 and may be removed in the future. The current behavior is equivalent to passing `weights=ResNet50_Weights.IMAGENET1K_V1`. You can also use `weights=ResNet50_Weights.DEFAULT` to get the most up-to-date weights.
#   warnings.warn(msg)

# %% [markdown]
# - Pre-Trained Model의 일부 Layer Freeze하기

# %%
ct = 0 
for child in resnet.children():  
    ct += 1  
    if ct < 6: 
        for param in child.parameters():
            param.requires_grad = False

# %% [markdown]
# - Transfer Learning 모델 학습과 검증을 위한 함수

# %%
def train_resnet(model, criterion, optimizer, scheduler, num_epochs=25):

    best_model_wts = copy.deepcopy(model.state_dict())  
    best_acc = 0.0  
    
    for epoch in range(num_epochs):
        print('-------------- epoch {} ----------------'.format(epoch+1)) 
        since = time.time()                                     
        for phase in ['train', 'val']: 
            if phase == 'train': 
                model.train() 
            else:
                model.eval()     
 
            running_loss = 0.0  
            running_corrects = 0  
 
            
            for inputs, labels in dataloaders[phase]: 
                inputs = inputs.to(DEVICE)  
                labels = labels.to(DEVICE)  
                
                optimizer.zero_grad() 
                
                with torch.set_grad_enabled(phase == 'train'):  
                    outputs = model(inputs)  
                    _, preds = torch.max(outputs, 1) 
                    loss = criterion(outputs, labels)  
    
                    if phase == 'train':   
                        loss.backward()
                        optimizer.step()
 
                running_loss += loss.item() * inputs.size(0)  
                running_corrects += torch.sum(preds == labels.data)  
            if phase == 'train':  
                scheduler.step()
 
            epoch_loss = running_loss/dataset_sizes[phase]  
            epoch_acc = running_corrects.double()/dataset_sizes[phase]  
 
            print('{} Loss: {:.4f} Acc: {:.4f}'.format(phase, epoch_loss, epoch_acc)) 
 
          
            if phase == 'val' and epoch_acc > best_acc: 
                best_acc = epoch_acc
                best_model_wts = copy.deepcopy(model.state_dict())
 
        time_elapsed = time.time() - since  
        print('Completed in {:.0f}m {:.0f}s'.format(time_elapsed // 60, time_elapsed % 60))
    print('Best val Acc: {:4f}'.format(best_acc))
 
    model.load_state_dict(best_model_wts) 

    return model

# %%
model_resnet50 = train_resnet(resnet, criterion, optimizer_ft, exp_lr_scheduler, num_epochs=EPOCH) 

torch.save(model_resnet50, 'resnet50.pt')
# Out:
# -------------- epoch 1 ----------------
# train Loss: 0.6040 Acc: 0.8167
# val Loss: 0.3521 Acc: 0.8852
# Completed in 5m 46s
# -------------- epoch 2 ----------------
# train Loss: 0.2341 Acc: 0.9258
# val Loss: 0.1943 Acc: 0.9375
# Completed in 5m 44s
# -------------- epoch 3 ----------------
# train Loss: 0.1647 Acc: 0.9466
# val Loss: 0.2744 Acc: 0.9204
# Completed in 5m 46s
# -------------- epoch 4 ----------------
# train Loss: 0.1440 Acc: 0.9524
# val Loss: 0.1324 Acc: 0.9592
# Completed in 5m 45s
# -------------- epoch 5 ----------------
# train Loss: 0.1132 Acc: 0.9628
# val Loss: 0.1836 Acc: 0.9439
# Completed in 5m 41s
# -------------- epoch 6 ----------------
# train Loss: 0.1016 Acc: 0.9665
# val Loss: 0.0939 Acc: 0.9697
# Completed in 5m 41s
# -------------- epoch 7 ----------------
# train Loss: 0.0961 Acc: 0.9697
# val Loss: 0.1262 Acc: 0.9616
# Completed in 5m 42s
# -------------- epoch 8 ----------------
# train Loss: 0.0422 Acc: 0.9860
# val Loss: 0.0476 Acc: 0.9842
# Completed in 5m 45s
# -------------- epoch 9 ----------------
# train Loss: 0.0306 Acc: 0.9897
# val Loss: 0.0374 Acc: 0.9884
# Completed in 5m 40s
# -------------- epoch 10 ----------------
# train Loss: 0.0265 Acc: 0.9917
# val Loss: 0.0356 Acc: 0.9894
# Completed in 5m 41s
# -------------- epoch 11 ----------------
# train Loss: 0.0213 Acc: 0.9928
# val Loss: 0.0337 Acc: 0.9901
# Completed in 5m 39s
# -------------- epoch 12 ----------------
# train Loss: 0.0199 Acc: 0.9933
# val Loss: 0.0317 Acc: 0.9897
# Completed in 5m 41s
# -------------- epoch 13 ----------------
# train Loss: 0.0194 Acc: 0.9934
# val Loss: 0.0313 Acc: 0.9894
# Completed in 5m 41s
# -------------- epoch 14 ----------------
# train Loss: 0.0169 Acc: 0.9942
# val Loss: 0.0316 Acc: 0.9905
# Completed in 5m 42s
# -------------- epoch 15 ----------------
# train Loss: 0.0156 Acc: 0.9949
# val Loss: 0.0305 Acc: 0.9899
# Completed in 5m 43s
# -------------- epoch 16 ----------------
# train Loss: 0.0151 Acc: 0.9952
# val Loss: 0.0306 Acc: 0.9902
# Completed in 5m 40s
# -------------- epoch 17 ----------------
# train Loss: 0.0134 Acc: 0.9955
# val Loss: 0.0276 Acc: 0.9901
# Completed in 5m 40s
# -------------- epoch 18 ----------------
# train Loss: 0.0136 Acc: 0.9956
# val Loss: 0.0313 Acc: 0.9894
# Completed in 5m 41s
# -------------- epoch 19 ----------------
# train Loss: 0.0140 Acc: 0.9950
# val Loss: 0.0286 Acc: 0.9917
# Completed in 5m 42s
# -------------- epoch 20 ----------------
# train Loss: 0.0133 Acc: 0.9956
# val Loss: 0.0264 Acc: 0.9916
# Completed in 5m 41s
# -------------- epoch 21 ----------------
# train Loss: 0.0125 Acc: 0.9962
# val Loss: 0.0270 Acc: 0.9907
# Completed in 5m 39s
# -------------- epoch 22 ----------------
# train Loss: 0.0122 Acc: 0.9960
# val Loss: 0.0290 Acc: 0.9906
# Completed in 5m 40s
# -------------- epoch 23 ----------------
# train Loss: 0.0122 Acc: 0.9962
# val Loss: 0.0263 Acc: 0.9912
# Completed in 5m 39s
# -------------- epoch 24 ----------------
# train Loss: 0.0122 Acc: 0.9958
# val Loss: 0.0268 Acc: 0.9906
# Completed in 5m 39s
# -------------- epoch 25 ----------------
# train Loss: 0.0131 Acc: 0.9958
# val Loss: 0.0278 Acc: 0.9904
# Completed in 5m 42s
# -------------- epoch 26 ----------------
# train Loss: 0.0120 Acc: 0.9964
# val Loss: 0.0296 Acc: 0.9912
# Completed in 5m 39s
# -------------- epoch 27 ----------------
# train Loss: 0.0118 Acc: 0.9962
# val Loss: 0.0277 Acc: 0.9909
# Completed in 5m 39s
# -------------- epoch 28 ----------------
# train Loss: 0.0122 Acc: 0.9960
# val Loss: 0.0299 Acc: 0.9905
# Completed in 5m 40s
# -------------- epoch 29 ----------------
# train Loss: 0.0121 Acc: 0.9963
# val Loss: 0.0248 Acc: 0.9914
# Completed in 5m 39s
# -------------- epoch 30 ----------------
# train Loss: 0.0118 Acc: 0.9962
# val Loss: 0.0316 Acc: 0.9896
# Completed in 5m 41s
# Best val Acc: 0.991739

# %% [markdown]
# ### 모델 평가

# %%
# 베이스라인 모델 평가를 위한 전처리 
transform_base = transforms.Compose([transforms.Resize([64,64]),transforms.ToTensor()])
test_base = ImageFolder(root='./splitted/test',transform=transform_base)  
test_loader_base = torch.utils.data.DataLoader(test_base, batch_size=BATCH_SIZE, shuffle=True, num_workers=4)

# %%
# 전이학습 모델 평가를 위한 전처리하기
transform_resNet = transforms.Compose([
        transforms.Resize([64,64]),  
        transforms.RandomCrop(52),  
        transforms.ToTensor(),
        transforms.Normalize([0.485, 0.456, 0.406], [0.229, 0.224, 0.225]) 
    ])
    
test_resNet = ImageFolder(root='./splitted/test', transform=transform_resNet) 
test_loader_resNet = torch.utils.data.DataLoader(test_resNet, batch_size=BATCH_SIZE, shuffle=True, num_workers=4)

# %% [markdown]
# - 베이스라인 vs 전이학습

# %%
baseline=torch.load('baseline.pt') 
baseline.eval()  
test_loss, test_accuracy = evaluate(baseline, test_loader_base)

print('baseline test acc:  ', test_accuracy)
# Out:
# baseline test acc:   93.86656652897734

# %%
resnet50=torch.load('resnet50.pt') 
resnet50.eval()  
test_loss, test_accuracy = evaluate(resnet50, test_loader_resNet)

print('ResNet test acc:  ', test_accuracy)
# Out:
# ResNet test acc:   99.17386406308674
